# %% [markdown]
# # More Than a Feeling
#
# This notebook will download music metadata from the Spotify API and use it to train an unsupervised model that associates songs together based on their audio features. The model will be used to create a playlist of songs that are similar to a seed song.

# %%
# %pip install spotipy

# %%
# Import necessary libraries
import os
import sys
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Import the Spotipy library
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Import libraries to use MusicBrainz API
import musicbrainzngs as mb

# Import the libraries for the Unsupervised Learning model
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Set the Spotify API credentials
os.environ["SPOTIPY_CLIENT_ID"] = "3d5abd956131402db5573fe68302d1ba"
os.environ["SPOTIPY_CLIENT_SECRET"] = "ccf62c34a64b447b962955498ed27ebd"

# Create the Spotify object
spot = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
# Define the function to create a DataFrame with the song titles and audio features of the top 1000 songs on Spotify
def get_top_1000_songs():
    # Create an empty DataFrame
    df = pd.DataFrame(columns=["song_title", "artist", "popularity", "acousticness", "danceability", "energy", "instrumentalness", "liveness", "loudness", "speechiness", "tempo", "valence"])
    
    # Get the top 1000 songs on Spotify
    for i in range(0, 1000, 50):
        results = spot.search(q="year:2021", type="track", limit=50, offset=i)
        for track in results["tracks"]["items"]:
            song_title = track["name"]
            artist = track["artists"][0]["name"]
            popularity = track["popularity"]
            audio_features = spot.audio_features(track["id"])[0]
            acousticness = audio_features["acousticness"]
            danceability = audio_features["danceability"]
            energy = audio_features["energy"]
            instrumentalness = audio_features["instrumentalness"]
            liveness = audio_features["liveness"]
            loudness = audio_features["loudness"]
            speechiness = audio_features["speechiness"]
            tempo = audio_features["tempo"]
            valence = audio_features["valence"]
            df = df.append({"song_title": song_title, "artist": artist, "popularity": popularity, "acousticness": acousticness, "danceability": danceability, "energy": energy, "instrumentalness": instrumentalness, "liveness": liveness, "loudness": loudness, "speechiness": speechiness, "tempo": tempo, "valence": valence}, ignore_index=True)
    
    return df

# %%
def get_top_1000_songs():
    # Create an empty list to store the dataframes
    dfs = []
    
    # Get the top 1000 songs on Spotify
    for i in range(0, 50, 50):
        results = spot.search(q="year:2021", type="track", limit=50, offset=i)
        for track in results["tracks"]["items"]:
            song_title = track["name"]
            artist = track["artists"][0]["name"]
            popularity = track["popularity"]
            audio_features = spot.audio_features(track["id"])[0]
            df = pd.DataFrame({"song_title": [song_title], "artist": [artist], "popularity": [popularity]})
            dfs.append(df)
    
    # Concatenate the dataframes into a single dataframe
    df = pd.concat(dfs, ignore_index=True)
    
    return df

# %%
# View the DataFrame
df = get_top_1000_songs()
df.head()
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\urllib3\connectionpool.py:878, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     877     log.debug("Retry: %s", url)
# --> 878     return self.urlopen(
#     879         method,
#     880         url,
#     881         body,
#     882         headers,
#     883         retries=retries,
#     884         redirect=redirect,
#     885         assert_same_host=assert_same_host,
#     886         timeout=timeout,
#     887         pool_timeout=pool_timeout,
#     888         release_conn=release_conn,
#     889         chunked=chunked,
#     890         body_pos=body_pos,
#     891         **response_kw
#     892     )
#     894 return response
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\urllib3\connectionpool.py:868, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     867 try:
# --> 868     retries = retries.increment(method, url, response=response, _pool=self)
#     869 except MaxRetryError:
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=3HTa0ufQtxHATYMKDpl5HD (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\spotipy\client.py:270, in Spotify._internal_call(self, method, url, payload, params)
#     269 try:
# --> 270     response = self._session.request(
#     271         method, url, headers=headers, proxies=self.proxies,
#     272         timeout=self.requests_timeout, **args
#     273     )
#     275     response.raise_for_status()
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\requests\adapters.py:510, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     509 if isinstance(e.reason, ResponseError):
# --> 510     raise RetryError(e, request=request)
#     512 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=3HTa0ufQtxHATYMKDpl5HD (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[15], line 2
#       1 # View the DataFrame
# ----> 2 df = get_top_1000_songs()
#       3 df.head()
#
# Cell In[14], line 12, in get_top_1000_songs()
#      10 artist = track["artists"][0]["name"]
#      11 popularity = track["popularity"]
# ---> 12 audio_features = spot.audio_features(track["id"])[0]
#      13 df = pd.DataFrame({"song_title": [song_title], "artist": [artist], "popularity": [popularity]})
#      14 dfs.append(df)
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\spotipy\client.py:1750, in Spotify.audio_features(self, tracks)
#    1748 if isinstance(tracks, str):
#    1749     trackid = self._get_id("track", tracks)
# -> 1750     results = self._get("audio-features/?ids=" + trackid)
#    1751 else:
#    1752     tlist = [self._get_id("track", t) for t in tracks]
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\spotipy\client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\i.lutticken\AppData\Local\anaconda3\lib\site-packages\spotipy\client.py:311, in Spotify._internal_call(self, method, url, payload, params)
#     309     except (IndexError, AttributeError):
#     310         reason = None
# --> 311     raise SpotifyException(
#     312         429,
#     313         -1,
#     314         f"{request.path_url}:\n Max Retries",
#     315         reason=reason
#     316     )
#     317 except ValueError:
#     318     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=3HTa0ufQtxHATYMKDpl5HD:
#  Max Retries, reason: too many 429 error responses

# %%
# %pip install musicbrainzngs

# %%
# Set the MusicBrainz API credentials
mb.set_useragent("Music Recommendation System", "1.0", "zenferno@gmail.com")    

# Define the function to get 1000 most popular songs from the MusicBrainz API using pandas.concat
def get_top_1000_mb_songs():
    # Create an empty list to store the dataframes
    dfs = []
    
    # Get the top 1000 most popular songs from the MusicBrainz API produced in the U.S.
    for i in range(0, 1000, 100):
        results = mb.search_recordings(limit=100, offset=i, query="date:2023 AND country:US AND type:single")
        for recording in results["recording-list"]:
            song_title = recording["title"]
            artist = recording["artist-credit"][0]["artist"]["name"]
            genre = recording["genre-list"][0]["name"] if "genre-list" in recording else None
            popularity = recording["ext:score"]
            df = pd.DataFrame({"song_title": [song_title], "artist": [artist], "genre": [genre], "popularity": [popularity]})
            dfs.append(df)
            print(song_title, artist, genre, popularity)

    # Concatenate the dataframes into a single dataframe
    df = pd.concat(dfs, ignore_index=True)

    return df

# %%
# View the DataFrame
df = get_top_1000_mb_songs()
# Out:
# Good Things Kaylee Bell None 100
# Sin The Last Arizona None 100
# Good Dreams The Last Arizona None 100
# When Summer Rolls Around Kaylee Bell None 100
# Nights Like This Kaylee Bell None 100
# pheromones XINA None 100
# Boots 'n All Kaylee Bell None 100
# Stuck Always Last None 100
# Nothing Lasts Emily Yacina None 100
# 1987 DIAMANTE None 100
# Outta My Head Jada Facer None 100
# You, Every Time Jada Facer None 100
# Always and Forever SERRA None 100
# Codependency Dial Tone None 100
# SUNSHINE - Da'Raja None 100
# Juicy Lucy Kareem Rahma None 100
# No, There's No Hope For You Remo Drive None 100
# hesitation rosie None 100
# Lil Birdie DJ Harrison None 100
# Heaven Levitation Room None 100
# Broke Down Engine Woody Platt None 100
# BREAK & TEAR! GR!N None 100
# Forgive Me Father J-BLEV None 100
# Castaway The Elovaters None 100
# Come And Get It The Elovaters None 100
# BEACHY Daddy Yankee None 100
# LA HORA Y EL DÍA Daddy Yankee None 100
# BEACHY (Play‐N‐Skillz House Remix) Daddy Yankee None 100
# Until I Can’t JONJEN None 100
# Iconic (feat. jax) Simple Plan None 100
# Santorini Beéle None 100
# Only Way Out Is Thru GhostDragon None 100
# The Greatest Time of Year Derrick Horne None 100
# All I Want For Christmas Frank Thompson Jr. None 100
# Mario's Gone Mad K0DINE None 100
# Where Good Things Grow Maygen & The Birdwatcher None 100
# Movimenta Marshmello None 100
# Coast Of Mexico Rome and Duddy None 100
# EX BOX Keri Sreb None 100
# Warriors (Epic Orchestral Version) Justine's Mic None 100
# Wreckage of the Fall Jayme Stone None 100
# Dragon Lady Reddex None 100
# Like You Mean It Steven Rodriguez None 100
# Touch Steven Rodriguez None 100
# Love Me Harder Steven Rodriguez None 100
# Alice Steven Rodriguez None 100
# Enemy (Epic Orchestral Version) Justine's Mic None 100
# This Moment East Of Eden None 100
# Santa Claus Is Coming To Town Hip Hop Boobly Show None 100
# Joy In The Morning (Remix) Tauren Wells None 100
# Til Death Do Us Party Groovie Ghoulies None 100
# Electric Black Nite Crash None 100
# Affliction Black Nite Crash None 100
# Born For Me Kisha Grandy None 100
# Batéla Kiazi Malonga None 100
# Mfiawukiri Kiazi Malonga None 100
# Time For Love The Yuletime Lifters None 100
# Time For Love (Instrumental) The Yuletime Lifters None 100
# Alone On Christmas Madison McFerrin None 100
# The Dream Adam Port None 100
# The Dream (extended mix) Adam Port None 100
# Isaiah 9:6 (Christmas Carol) LaTonja Blair None 100
# Christmas In The City Gary Louris None 100
# The Christmas Waltz Brianna Kočka None 100
# 超獣戯画 超学生 None 100
# 1. Cuz of U Medium Build None 100
# Popola Marshmello None 100
# i am not who i was Chance Peña None 100
# Graves Seven Inch Heels None 100
# Dracula Seven Inch Heels None 100
# Still Here Silent Monk None 100
# Back 2 U Oh, Rose None 100
# Suddenly Tenth Avenue North None 100
# Heart On Fire In Mexico Abby Anderson None 100
# Heart On Fire In Mexico Abby Anderson None 100
# First To Hit The Road Abby Anderson None 100
# This Guy Abby Anderson None 100
# First To Hit The Road Abby Anderson None 100
# Heart On Fire In Mexico Abby Anderson None 100
# Circles Abby Anderson None 100
# Go ELI None 100
# Life goes on ELI None 100
# LIES ELI None 100
# Era Chimæra honabai None 100
# Broken Sky Ray LaMontagne None 100
# It Takes Me Back Ray LaMontagne None 100
# GRIZZCLL-FrighteningButBlissful GRIZZ CLL None 100
# Dead to the World Noel Gallagher’s High Flying Birds None 100
# Pretty Boy Noel Gallagher’s High Flying Birds None 100
# Pretty Boy (Robert Smith remix) Noel Gallagher’s High Flying Birds None 100
# We’re Gonna Get There in the End (7” mix) Noel Gallagher’s High Flying Birds None 100
# Pretty Boy Noel Gallagher’s High Flying Birds None 100
# Easy Now Noel Gallagher’s High Flying Birds None 100
# Magic Trick The Orange Goodness None 100
# Desconocidos Sinego None 100
# You're Always Coming Back Pardyalone None 100
# Grifo Tipa Tipo None 100
# Gwacter SYBS None 100
# Silent Night Dj Christology None 100
# Go Tell It Forrest Frank None 100
# Iznotreal meg elsier None 100
# Baby meg elsier None 100
# Ifshitfuq meg elsier None 100
# Carol of the Bells KenZee None 100
# Tan Lines SUM SUN None 100
# Mine Todd Carey None 100
# Golden Age NCT None 100
# ECR Vylet Pony None 100
# House Along the Road MARO None 100
# Casio Magic Coyote Island None 100
# Everyone Need Love Coyote Island None 100
# It’s Always Over Glitterfox None 100
# Crazy (Klubjumpers Remix) Jade Starling None 100
# Crazy (E39 Solstice Remix) Jade Starling None 100
# Crazy (Mr Mind Remix) Jade Starling None 100
# Crazy (Country Club Martini Crew Remix) Jade Starling None 100
# Crazy (Sam Gee Remix) Jade Starling None 100
# Crazy (Stonebridge High St Mix) Jade Starling None 100
# Crazy (Okjames Remix) Jade Starling None 100
# Crazy (Dark Intensity Remix) Jade Starling None 100
# Crazy (Larry Peace Remix) Jade Starling None 100
# Crazy (Block & Crown Remix) Jade Starling None 100
# Goth Girl Dinner Not Enough Space None 100
# Nightmares Not Enough Space None 100
# No Way Out Not Enough Space None 100
# Don't Be Scared Not Enough Space None 100
# Sew My Eyes Not Enough Space None 100
# The Line (Donnie Darko Edit) J-LOWER None 100
# Scene for an Exit Levitation Room None 100
# Cool It, Baby Levitation Room None 100
# Liar Liar DYLAN None 100
# Junebug Nikki & The Barn Boys None 100
# Indigo Nikki & The Barn Boys None 100
# One Day Deitrick Haddon None 100
# Don't Let the Roses Go Dry Nikki & The Barn Boys None 100
# Lines Drawn Dee-1 None 100
# Greedy Rain Paris None 100
# Deck the Halls The Lumineers None 100
# Just For You (L.L.Bean Christmas Advert) Olivia Dean None 100
# Miracles Casey Barnes None 100
# Postcard Byland None 100
# Monstera Byland None 100
# 7711 Felix Ames None 100
# Taxi Driver Felix Ames None 100
# Sounds Like Freedom Tylynn None 100
# Thank You For Listening Joshua Ray Walker None 100
# Whiskey Lullaby Drew Jacobs None 100
# I Would If I Could Lainey Wilson None 100
# Million Other Things India Naia None 100
# Song of Joy David Tolk None 100
# Este Amor Rosemarie None 100
# Love Like This Rosemarie None 100
# Baby Don't ZZ Ward None 100
# Pit stop Bakar None 100
# On & On (Again) [extended mix] Confidence Man None 100
# On & On (Again) Confidence Man None 100
# On & On (Again) - VIP Confidence Man None 100
# Christmas in Hollis (Sped Up) Run‐D.M.C. None 100
# Christmas in Hollis (Slowed & Reverb) Run‐D.M.C. None 100
# You Did It Before Classmaticc None 100
# I Think About Corey Paul None 100
# Seven Veils Humbird None 100
# Child of Violence Humbird None 100
# Viens chez moi SOLEIL ROUGE None 100
# No Brakes Blake Fades None 100
# Odyssey Beck None 100
# Thinking About You Beck None 100
# Odyssey (instrumental) Beck None 100
# When the Magic Dies Culture Code None 100
# After Us dreamr. None 100
# In My Heart N3WPORT None 100
# Woman Life Freedom Sahara Dawn None 100
# Goodness Praise Break (Radio) Digital Native None 100
# Goodness Praise Break (Main) Digital Native None 100
# Goodness Praise Break (Instrumental) Digital Native None 100
# Bless The Lord Michelle Prather None 100
# Fear Not Matthew Aarons None 100
# For the Rest of My Life Mark Hubbard and the Voices None 100
# Work It Out MarQuez Curtis None 100
# No One Greater Malik Oliver None 100
# Realest Ez Mil None 100
# 300 ZX Jered Sanders None 100
# Life Before Life Crushed the Life out of Us Brandon Invergo None 100
# Good With My Soul King Chav None 100
# Change Locations Parris Chariz None 100
# Carry Me Eris Ford None 100
# La Discoteca BIIANCO None 100
# List Of Things To Do Rose Droll None 100
# I'm Finished Tuu B. None 100
# Wade In The Water Yona Marie None 100
# Burn, Heal, Repeat (Clowns vs Nazis - Rosu) Rabbit Junk None 100
# Deja Vu Dynoro None 100
# LAST CHRISTMAS YOU WERE MINE Acidgvrl None 100
# Summer Nights Casey Barnes None 100
# HI YA YA (แค่มีเธอ) 4MIX None 100
# Closure Mat Zo None 100
# Bands Derek Minor None 100
# Remembering the Rose Lucinda Chua None 100
# Rose Garden Lucinda Chua None 100
# The Maze Lucinda Chua None 100
# Selassie is the Chapel Bob Marley & The Wailers None 100
# No Stressing Damon Little None 100
# GUNSHY Allie Kelly None 100
# Comedown Calicos None 100
# The Siren Calicos None 100
# Reliving Calicos None 100
# Kam Duval Timothy None 100
# The Dream (radio edit) The Flower Kings None 100
# Night Bird Crusade None 100
# I Don’t Wanna Worry NEEDTOBREATHE None 100
# Sweet Sounds of Heaven (live at Racket, NYC) The Rolling Stones None 100
# Sweet Sounds of Heaven (edit) The Rolling Stones None 100
# Unlovable Beach Weather None 100
# One of a Kind Love Affair Kadhja Bonet None 100
# Lyin' Caden McGuire None 100
# Fine & Dandy Graycie York None 100
# Family Affair Graycie York None 100
# Sober Graycie York None 100
# Marlboro Magic Graycie York None 100
# True To Our Love Alek Vila None 100
# In Dulci Jubilo David Tolk None 100
# What Do You Do? Caden McGuire None 100
# Down Bad Caden McGuire None 100
# Pac-Man Kaedyn None 100
# This Side George.Rose None 100
# Rule the World (extended mix) ricky retro None 100
# Rule the World ricky retro None 100
# One Like You LP None 100
# Need Alekisok None 100
# Resonance x Genesis x Not Allowed Alekisok None 100
# Две девочки (Sped Up) Alekisok None 100
# Save Me (From Myself) NURKO None 100
# Save Me from Myself Man Cub None 100
# teeth (single version) bloody saliva None 100
# I'm a Little Bitch (Demo) Rotting Fruit None 100
# Go Away (Demo) Rotting Fruit None 100
# Praise Your Name Angela Moss Poole None 100
# Feel It Deep Inside Dopamine None 100
# Feel It Deep Inside (VIP) Dopamine None 100
# Good News Bakar None 100
# Only God Bonita Burney Simmons None 100
# Thanksgiving Prayer A. Savage None 100
# Unbreakable Knox Hill None 100
# calm & patient Jhené Aiko None 100
# OVERKILL JILUKA None 100
# In Your Life (Lisa Tomlins version) Lord Echo None 100
# Reckless & Sweet Amaarae None 100
# Psychedelic Ritmo Machine None 100
# Gun Powder Calibro 35 None 100
# Way Down in Mississippi Jason Eady None 100
# No Struggle, No Strength K‐Drama None 100
# Axis Lande Hekt None 100
# Pottery Class Lande Hekt None 100
# Worth It Joseph Madigan None 100
# Forward March Sober Minded None 100
# Chase the Dragon Civic None 100
# Something About This Place Thrillhouse None 100
# Electric Fire Thrillhouse None 100
# So Far From Where I Started From Thrillhouse None 100
# Never Given a Chance Thrillhouse None 100
# A Better Kind of Shot Thotcrime None 100
# A Typical Story 박제형 None 100
# Concrete Hell Terminal Nation None 100
# A Pound of Flesh or a Gallon of Blood Terminal Nation None 100
# Oceans Gryffin None 100
# Because The Night (feat. AISKA & Julian Black) Housewerk None 100
# Your Power Lecrae None 100
# Kept in Heaven (1 Peter 1:6-9) Ri-An None 100
# Peep Torey D'shaun None 100
# Sintonía Bacs None 100
# Sugarwater Mungo’s Hi Fi None 100
# Yours Danielle Apicella None 100
# Antiamorous Omerta None 100
# Estranged Fruit Fishbone None 100
# Distracted Logan Lynn None 100
# Бабушка Пневмослон None 100
# Бабушка (cut) Пневмослон None 100
# You Wande None 100
# ChristWork Brinson None 100
# Home Run Canon None 100
# I Mean Jesus All The Way Anisa Fowler None 100
# Witch Museum Landowner None 100
# Moving By The Power Of God Jarell Smalls None 100
# The Sound of Hunger Obsidian Mind None 100
# Comin’ To Your City (ESPN College Gameday) The Cadillac Three None 100
# The Pool Mayer Hawthorne None 100
# Menace Aha Gazelle None 100
# Mia Blacklist Union None 100
# Western Worlds Ruth Garbus None 100
# Not To Worry Valexa Daya None 100
# Riding On Stars Valexa Daya None 100
# Swing On Valexa Daya None 100
# Heavy Chops Palm Palm None 100
# Grip Palm Palm None 100
# Out on Bail Palm Palm None 100
# Huffing Bois Palm Palm None 100
# I & I Palm Palm None 100
# Nudge FIDLAR None 100
# If You Know Desire Marea None 100
# If You Know (single version) Desire Marea None 100
# Waste Your Love WildVibes None 100
# Different Kinda Love Mari Bella None 100
# Mata Leão Ezediel None 100
# CUFF IT (A CAPELLA) Beyoncé None 100
# CUFF IT (INSTRUMENTAL) Beyoncé None 100
# Somebody Loves You Jordan Feliz None 100
# The King is Alive Jordan Feliz None 100
# Rock Bottom Levi Hummon None 100
# Can't Call It Greg Grease None 100
# On Your Mind Travis Atreo None 100
# Love Lee AKMU None 100
# Асансьора Боро Първи None 100
# Roses Hunter Hayes None 100
# Sinners & Saints Like a Storm None 100
# Side Hug eleventyseven None 100
# Opaque eleventyseven None 100
# Look At God Koryn Hawthorne None 100
# Pony Slothrust None 100
# Living Water Crown Of Victory None 100
# Revival Kit Miles Minnick None 100
# Aint That Something Tylynn None 100
# 후라이의 꿈 AKMU None 100
# wanted Heather Sommer None 100
# Smoking Gun Stellar None 100
# Golden Years Stellar None 100
# Empty as the Grave Josiah Queen None 100
# Gamora Ben Noble None 100
# Fishes and Loaves Josiah Queen None 100
# I am Barabbas Josiah Queen None 100
# The Prodigal Josiah Queen None 100
# Never Tasha Layton None 100
# Chemicals Matt Hansen None 100
# Break My Bones Matt Hansen None 100
# Where You Belong Matt Hansen None 100
# Lifejacket Matt Hansen None 100
# in the dark gavn! None 100
# All My Best Years gavn! None 100
# I Miss Who You Were Zach Seabaugh None 100
# Maybe We Do Zach Seabaugh None 100
# Not How I Want To Zach Seabaugh None 100
# Co-Pilot Zach Seabaugh None 100
# Hair-ties & Lighters Dune Laila None 100
# Him Dune Laila None 100
# Get High Derecho Rhythm Section None 100
# Impossible Day Derecho Rhythm Section None 100
# Somewhere Voctave None 100
# Thank You For Loving Me Greg Logins and Revival None 100
# High Pressure Days W. H. Lung None 100
# King of the Slugs Fat Dog None 100
# Feeling Good Foreword Nation None 100
# You're Gonna Win Johnny Ruffin Jr. None 100
# Help! Aklesso None 100
# New Year’s UnResolution L’Rain None 100
# The Day That I’m Over You Danielle Bradbery None 100
# Bury Me With My Guitar Jameson Rodgers None 100
# If I Was Doing Any Better Jameson Rodgers None 100
# Whiskey Train Jameson Rodgers None 100
# Hollow Heart C. James None 100
# Keep Me In Mind Jimmy DoGood None 100
# afterglow in ohio Deathcruiser None 100
# Back to Life Poolside None 100
# Jealousy Junkyard Jet None 100
# Stand By Me No Resolve None 100
# VANESSA RYKEYDADDYDIRTY None 100
# Magnet On Your Refrigerator Ben Cook-Feltz None 100
# America Tobacco City None 100
# Motorcade Tobacco City None 100
# Crazy DeathbyRomy None 100
# Late Nights DeathbyRomy None 100
# I’m Jus’ Fuckin’ With U Gurl (clean version) Thuggizzle None 100
# RIGHT OR WRONG (HYPNOSIS) Pitbull None 100
# Through Love Donnell Isaac None 100
# 1525 Flame None 100
# Wild & Free Wande None 100
# Turn Your Face Into the Sun The Streets None 100
# CUFF IT (A CAPELLA) Beyoncé None 100
# Ride Pon It (feat. Warrior Queen) [Deekline & Liondub Remix] Deekline None 100
# Dream of You Deekline None 100
# Rule the Dance (feat. Christina Nicola) Deekline None 100
# It's Looking Up Katrae Washington None 100
# Pandemonium International Show None 100
# My Matter Limoblaze None 100
# 2002 Phil J. None 100
# In the Silence Voicians None 100
# L+E Voicians None 100
# Just a Beat Voicians None 100
# If You Don’t IMERIKA None 100
# In My Head Nell Mescal None 100
# Go to Hell! Vaeo None 100
# Anomaly I See Stars None 100
# Drift I See Stars None 100
# Closer Da'Gatherer None 100
# Hyperion Mike Bass None 100
# Shatter Starsign None 100
# DAISIES Kinfu None 100
# TIGHTROPE Kinfu None 100
# SUMMER SKY HENRY None 100
# El Sol Me Da Bad Gyal None 100
# Herbergsvater (Tri Tra Trullala) (Mix 90 Extended Version) (2023 Remaster) Joachim Witt None 100
# Herbergsvater (Tri Tra Trullala) (Mix 90 Single Version) (2023 Remaster) Joachim Witt None 100
# Tri Tra Trullala (Herbergsvater) (Single Version) (2023 Remaster) Joachim Witt None 100
# Tri Tra Trullala (Herbergsvater) (2023 Remaster) Joachim Witt None 100
# Geh mal vor (2023 Remaster) Joachim Witt None 100
# Love You More Dream Wife None 100
# Phantom Menace 黒衣 None 100
# gentle rain Sachiho None 100
# Balance NAO None 100
# Across The Mountains Kristen Grainger & True North None 100
# Are You Okay? Arctic Lake None 100
# bandages Lexi Jayde None 100
# Hanataba 川口ゆりな None 100
# Forget Me Knots Kendall Lujan None 100
# Hold Me The Seshen None 100
# Manny, Manny! Stereosity None 100
# Hella drugs Brakanah 44 None 100
# Sweet Life Rival Sons None 100
# Single Soon (instrumental version) Selena Gomez None 100
# Toxic (live acoustic) aeseaes None 100
# Seven Nation Army (live acoustic) aeseaes None 100
# Chloë Heart to Gold None 100
# Pop My Shit E‐40 None 100
# sunshine Rio Rainz None 100
# Blicky Bop Fly Anakin None 100
# Molly Jo Trevor Martin None 100
# Ain't the Aisle Trevor Martin None 100
# Thinkin' Bout Trevor Martin None 100
# One Weird Tip (Drums) Lemon Demon None 100
# Funkytown (Instruments) Lemon Demon None 100
# Funkytown (Vocals) Lemon Demon None 100
# One Weird Tip (Instruments) Lemon Demon None 100
# One Weird Tip (Vocals) Lemon Demon None 100
# Funkytown (Drums) Lemon Demon None 100
# WIERDNESS Neil Cicierega None 100
# One Weird Tip (Bass) Lemon Demon None 100
# Funkytown (Bass) Lemon Demon None 100
# Neon Wasteland Madeline Hawthorne None 100
# Right on Time Them Vibes None 100
# Both Of Us - Edit Jayda G None 100
# Circle Back Around Jayda G None 100
# Are U Down Jayda G None 100
# Dysphoria killusonline None 100
# Can't Call You Beautiful Trevor Martin None 100
# What If We Were? Trevor Martin None 100
# Realm of Minor Angels The Church None 100
# Synthetic Synergy José Julián Soberanis None 100
# Blessing Samantha Moon None 100
# Ghosted Craishon None 100
# IG Pi’erre Bourne None 100
# Worry Roderick Newport None 100
# Let Somebody Love You Cruz Contreras None 100
# Get It Karma Fields None 100
# Dame Un Break Rawayana None 100
# 你瞞我瞞 - From THE FIRST TAKE 陳柏宇 None 100
# 有天 - From THE FIRST TAKE 陳柏宇 None 100
# Take Care Jacob Furr None 100
# Dom Dom Yes Yes Biser King None 100
# SUGAR DIVE Wesley Joseph None 100
# HIATUS Wesley Joseph None 100
# COLD SUMMER Wesley Joseph None 100
# MONSOON Wesley Joseph None 100
# Amor de locos Timbalive None 100
# BLOOD (Demon voice) Brakanah 44 None 100
# Wem die Stunde schlägt Oomph! None 100
# Richter und Henker Oomph! None 100
# Wem die Stunde schlägt Oomph! None 100
# Unseen SLIFT None 100
# The Real Unseen SLIFT None 100
# Gold Tristan Palmer None 100
# Don't Wanna Tristan Palmer None 100
# Somebody to You Rachael Lampa None 100
# MirrorInPlainSight Guns For Frogs None 100
# The Horizon (with You) DubVision None 100
# The Catch Clare Doyle None 100
# Big Pimpin’ Rich the Kid None 100
# Big Pimpin’ Rich the Kid None 100
# luh loud <3 bappy None 100
# lebron james gif bappy None 100
# FAux PERFECTiON cillism None 100
# The Otherside ACRAZE None 100
# Dancefllor NOISY None 100
# The Motive NOISY None 100
# Washed Up Meredith Edgar None 100
# Trust God Rawsrvnt None 100
# Hotline Soulfire Bree None 100
# Eat Your Young (Bekon’s Choral version) Hozier None 100
# You Knew (Payfone remix) Róisín Murphy None 100
# You Knew (Eli Escobar remix) Róisín Murphy None 100
# Out of My Head Man Plus None 100
# A Great Wild Mercy Carrie Newcomer None 100
# Bend The Whip Canon None 100
# Closer I Get Margo Price None 100
# Strays Margo Price None 100
# Malibu Margo Price None 100
# Role Quoiny None 100
# Freedom Brandon Love None 100
# Confetti Trip Lee None 100
# Money To Make Remix Da'cleevlindian None 100
# Who Do I Trust (Me) LeBartlett None 100
# Never Gave Up On Him Davey Holler None 100
# Nothing But The Blood Forrest Frank None 100
# Step Into the Light Dee-1 None 100
# Gardens Barbaro None 100
# Fresh Ari Joshua None 100
# Cut Your Face The Joy Formidable None 100
# Fire of Mercy Hot Chip None 100
# Deep In the Night Future Islands None 100
# Dream Again SmallTown Strings None 100
# Duell der Letzten Tränen None 100
# Kapitulation Tränen None 100
# Stures dummes Herz Tränen None 100
# Charm You Samia None 100
# Under the Sun Spellling None 100
# Cherry Spellling None 100
# Be Somebody Rasmus Hagen None 100
# Lemonade Keir None 100
# Lean On Rain Paris None 100
# Further Away Goodboys None 100
# Jar of Hearts Madilyn Bailey None 100
# Party O’Clock (inst.) NMIXX None 100
# Roller Coaster (inst.) NMIXX None 100
# Roller Coaster NMIXX None 100
# Party O’Clock NMIXX None 100
# Inner Strength Alan C. Jackson None 100
# I'm Up Knick Knack None 100
# Pulling Threads The Briefly Gorgeous None 100
# When the Demons Call John Swardson None 100
# CRUEL WORLD $NOT None 100
# Fast Forward NIIKO X SWAE None 100
# Anomaly Kylie V None 100
# Rule the World (Everybody) Tiësto None 100
# Psycho Brooks Nielsen None 100
# Learned to Love Getting High Brooks Nielsen None 100
# Druggy Drug Drugs Brooks Nielsen None 100
# Хаус ритм Лаванда None 100
# Byrd And Shepard Kam Franklin None 100
# Asteroids Rapsody None 100
# Some News (ft. Okkervil River) Will Sheff None 100
# Tommy McHugh (ft. Okkervil River & Bridget St. John) Will Sheff None 100
# On Fire for Love José Julián Soberanis None 100
# Capacity Michael Gelinas None 100
# Mujhe Mere Naam Se The Yellow Diary None 100
# Venomous (Clean Version) DJ Scandalous None 100
# Venomous (Instrumental) DJ Scandalous None 100
# Venomous (A capella) DJ Scandalous None 100
# Venomous (Album Version) DJ Scandalous None 100
# IdgaF Audrey Nuna None 100
# locket Audrey Nuna None 100
# Yolum Açık Güneş None 100
# LOVELESS Dios None 100
# In My Head (Spooky version) Mike Shinoda None 100
# In My Head (A Cappella) Mike Shinoda None 100
# In My Head (Instrumental) Mike Shinoda None 100
# In My Head (Slowed and Reverbed) Mike Shinoda None 100
# In My Head (Sped Up) Mike Shinoda None 100
# Who By Fire Skinny Pelembe None 100
# She Riding Fetty Wap None 100
# taurus ko aka koala None 100
# tqum Sofía Reyes None 100
# HOY ME PORTO MAL Sofía Reyes None 100
# Do It So Good WARGASM None 100
# Awkward Weakened Friends None 100
# Artist Final Body None 100
# FLATLINE Frost Children None 100
# And It’s All Guns and Arrows (12” Version) Car Colors None 100
# Old Death (12” Version) Car Colors None 100
# I’ll Bear (12” Version) Car Colors None 100
# Broken Number 13 Soft Release None 100
# Bike Lock Aiden Intro None 100
# Hekima A.I. The Anomaly None 100
# Zapped J. Johnson None 100
# Bossa Nova Kham None 100
# Fools Gold Such A Pretty Face None 100
# 40,000 FT. K‐Drama None 100
# Over Limoblaze None 100
# BOCHINCHE Dawer x Damper None 100
# Runnin’ (feat. Dream Mclean, Dame & Wallace Rice) Ebi Soda None 100
# Runnin’ (Instrumental) Ebi Soda None 100
# Coming Of Age Van Houten None 100
# (nevermind) ammar None 100
# holy silence, interlude ammar None 100
# Sandy Don't Thank Me Spank Me None 100
# Pharmakon (Reimagined) Humbird None 100
# Strong Enough (Goodwerks) Humbird None 100
# Help Me Willie Nelson! Humbird None 100
# Greensleeves Humbird None 100
# Cornfields and Roadkill Humbird None 100
# North Country Girl Humbird None 100
# Persephone (Reimagined) Humbird None 100
# Put it Down Otis McDonald None 100
# Pathways (feat. Wil Blades) Otis McDonald None 100
# The Window Ruthven None 100
# Beyond Sick Yeat None 100
# Heart in Pain Doro None 100
# Sunset Mother of Graves None 100
# this is what space feels like JVKE None 100
# The Vagrant Soul The Silver None 100
# Boulevard Of Broken Dreams (Reggae Cover) Stick Figure None 100
# FΛSHION (Speed Up) Britney Manson None 100
# FΛSHION (Slow) Britney Manson None 100
# Sleep in Peace AllttA None 100
# Strangers Young Bombs None 100
# Very Complex Campus Christy None 100
# Meji Meji (Folamour Remix) Bosq None 100
# Take My Chance MK None 100
# Take My Chance (extended) MK None 100
# Pull You Closer Sistek None 100
# Lafayette Arcwelder None 100
# Take It Slow Arcwelder None 100
# Auld Lang Syne The Dollyrots None 100
# Affectations TREMOURS None 100
# On The Wall TREMOURS None 100
# Dark Glasses (Pete International Airport Remix) TREMOURS None 100
# Dark Glasses TREMOURS None 100
# Hallelujah Kimberly Perry None 100
# You Knew (edit) Róisín Murphy None 100
# Fader (edit) Róisín Murphy None 100
# The Universe (edit) Róisín Murphy None 100
# FCKNSTR Britney Manson None 100
# FΛSHION (Remix) Britney Manson None 100
# Magnets in the Dark Young Bombs None 100
# Ideograma Media Hermana None 100
# Impermanent I Asha Wells None 100
# Solteiro Sou um Perigo Marshmello None 100
# Like Coconut Water BALTHVS None 100
# Anouk BALTHVS None 100
# Gift of Life Brainstory None 100
# Nobody But You Brainstory None 100
# Karma Rain Paris None 100
# LEFT FOR DEAD Witchouse 40k None 100
# Untitled Visions Monophonics None 100
# Bam Paint None 100
# All Too Real Art of Dying None 100
# The General Guns N’ Roses None 100
# Genie in a Bottle Bill Kaffenberger None 100
# I Believe In Love Again (Jex Opolis Remix Edit) Peggy Gou None 100
# ROBLOX IN A NUTSHELL Lil Ch3mix None 100
# Trading (remix) Dave Hall None 100
# New Born King Dalon Collins None 100
# Désenchantée (extended mix) Kate Ryan None 100
# A Night At Orleans Shin‐Ski None 100
# Downtown Vibes Shin‐Ski None 100
# Full Moon Night Frute None 100
# All Star (Medieval version) Bardcore None 100
# Every Breath You Take (Medieval version) Bardcore None 100
# Never Gonna Give You Up (Medieval version) Bardcore None 100
# Bad Habit (Medieval version) Bardcore None 100
# Always Crossed My Heart K. Kawaii None 100
# Heavy Gunner (Instrumental) Sivion None 100
# Heavy Gunner Sivion None 100
# Love Beyond the Grave Crocodiles None 100
# Malibu Ritmo Machine None 100
# Another Man obli None 100
# Safe to Say Vena Morris None 100
# Between These Ears Moreish Idols None 100
# Blessed Aaron Lindsey None 100
# Trusting God (Radio Edit) James Fortune None 100
# Trusting God James Fortune None 100
# Insane Dinner Party None 100
# Kill Tha King (Radio Edit) Serious Voice None 100
# Kill Tha King Serious Voice None 100
# Up Aaron Cole None 100
# Astro Lab Omar Offendum None 100
# Winning Wande None 100
# OH YHWH Angie Rose None 100
# Feel You're Here Fresh Start Worship None 100
# Solar Power MELONYX None 100
# Solar Power (Instrumental) MELONYX None 100
# Ain't A Damn Thang Hackey OG None 100
# Six Stars Cassandra Lewis None 100
# Morning Light Dilly Dally None 100
# Broke Scene Gordi None 100
# Colour of Joy Dilly Dally None 100
# Didn't Want to Have to Do It Lady Apple Tree None 100
# Never Going Back Tyrone Crawford None 100
# Planet You Snapped Ankles None 100
# Kingdom PTtheGospelSpitter None 100
# Do It Faster Militarie Gun None 100
# Shotgun Willie Margo Price None 100
# Commie Ska Cop / Out None 100
# Kill Em Dead Faintest Idea None 100
# Consumerism Acid Tongue None 100
# I Was Not There (Edit) The Antlers None 100
# I Was Not There The Antlers None 100
# Esteeming Ratta Ka Kat None 100
# 2 Pairs Hackey OG None 100
# Snow On Tha Bluff Hackey OG None 100
# Good Times Hackey OG None 100
# Lay Up Hackey OG None 100
# No Relation Hackey OG None 100
# He Wanted More Hackey OG None 100
# Myopic Drug Church None 100
# No Thugs Hackey OG None 100
# Ahead of Time AmaurisWill None 100
# Ghost Brevin Kim None 100
# ShoulderBlades Brevin Kim None 100
# Mind How You Go Tomten None 100
# Fire Fall Seth & Nirva None 100
# Brain UnChain Cadillac Muzik None 100
# High Sierra Lows Windows None 100
# Shots Fired Blessed by a Broken Heart None 100
# Safe and Sound Point North None 100
# Jesus is my home R. Collins None 100
# Chopsticks Choirboy Bell None 100
# Long-While Windows None 100
# The Ghost's Prequel J. Johnson None 100
# Good Ol' Boys with Bad Names Logan Halstead None 100
# Photo PARALLELZ None 100
# Anam Cara Annie Fitzgerald None 100
# Red Dirt Girl Sunny Sweeney None 100
# Pambelé Captain Planet None 100
# Pearl Machine The Mary Onettes None 100
# Easy Hands The Mary Onettes None 100
# Please Don’t Ebi Soda None 100
# Please Don’t (Instrumental) Ebi Soda None 100
# Like You Bizzle None 100
# President nobigdyl. None 100
# Doing It Up Phathom None 100
# Rhinestone Teardrops Molly Brandt None 100
# 闇の空 (DARK SKIES VIP) Ruby May Valentine None 100
# 闇の空 (INSTRUMENTAL) Ruby May Valentine None 100
# 闇の空 (LP VERSION) Ruby May Valentine None 100
# Don't Be Afraid Marr Grey None 100
# Halloween Fizz StarJake None 100
# Void StarJake None 100
# Fatal Note StarJake None 100
# Purgatory (Outro) StarJake None 100
# Tweakatchu StarJake None 100
# Animals in War Trust Fund None 100
# Man Of The House Kham None 100
# Find My Way Back Mumu Fresh None 100
# Secret Lover MC Ba7a None 100
# Closer Dee Black None 100
# Megaphone J. Monty None 100
# Food Of Me GIO. None 100
# Desert Road [ft. CAIN] Casting Crowns None 100
# Cramps Slow Pulp None 100
# Beautiful Colours Mayfair Laundry None 100
# lonely okayceci None 100
# Cocaine Bear Yarn None 100
# You Don't Know Nothin' Yet The Vaughan Building None 100
# Glimpse Interupt None 100
# Forest NomiS None 100
# Hurt King Coop None 100
# whatchaknow. Reneé None 100
# hate. Reneé None 100
# hoes. Reneé None 100
# Staircase Umphrey’s McGee None 100
# Come on, Aphrodite Natalie Merchant None 100
# You Can Have Her Elvis Costello None 100
# Sports Day Gilla Band None 100
# Fools Gold - Billy & The Kidz None 100
# Covered in Roses No One Mind None 100
# Riddle Remix (w/Mark Refoy) Chatham Rise None 100
# Splinter Chatham Rise None 100
# What I’m Missing GracieHorse None 100
# Run Ricky Run GracieHorse None 100
# Complete Me BrianaRae None 100
# ラストノート (オリジナル・カラオケ) 藤井香愛 None 100
# 夢告鳥 (オリジナル・カラオケ) 藤井香愛 None 100
# Like The Weekend BrvndonP None 100
# Heart to Heart Crowns Down None 100
# God Is Good Charmaine Danielle None 100
# Misdemeanour AD/VR None 100
# On Time Ashford Sanders None 100
# God Is Antoine Hilton None 100
# Already Won B. Cooper None 100
# Spend A Little Time Chel Hill None 100
# Piece Of Mind Gerry Skrillz None 100
# My Happy Dee-1 None 100
# The Ghost's Prequel J, Johnson None 100
# Once on Another Day Bonny Light Horseman None 100
# Fisherman Thre None 100
# Panoramic Mvkeyyj None 100
# Too Sus Mike Sarge None 100
# El Dorado Sky Cadillac Muzik None 100
# Black Hearses Twiceborn None 100
# Losing My Religion (Medieval version) Bardcore None 100
# Hide Me Dante Bowe None 100
# Poets, Politricks and Propaganda Freshman Woes None 100
# Big! Miles Minnick None 100
# Get Up Cheryl Boggs None 100
# Magnificent (remix) Dynasty None 100
# 23 NLE Choppa None 100
# I Believe God Jekalyn Carr None 100
# 夢告鳥 藤井香愛 None 100
# ラストノート 藤井香愛 None 100
# Through It All Ilan Bell None 100
# Love Roderick Newport None 100
# A Short Song Roderick Newport None 100
# Take It Away (Pt. A) S.G. Goodman None 100
# Take It Away (Pt. B) S.G. Goodman None 100
# Take It Away S.G. Goodman None 100
# My Passion (remix) B.E.R.I.D.O.X. None 100
# Sober! Miles Minnick None 100
# Doomsday Clock NomiS None 100
# Know What I Mean Vic Lucas None 100
# Serious Dance Music Avalanche Party None 100
# God's Love Sketch A Peaze None 100
# War Boys Weep Wave None 100
# Fist City Shelly Fairchild None 100
# Horizon Taina Asili None 100
# Flood Into Fazerdaze None 100
# Stuck On The Elevator Torey D'shaun None 100
# mean GULES None 100
# Let's Talk It Out James Intveld None 100
# Lost (Mycenae Mix) Solina Tuuli None 100
# Bringing the Worst Valletta None 100
# Darkness Turns to Light (from BEYBLADE BURST QUADSTRIKE) Our Last Night None 100
# golden hour Our Last Night None 100
# Fear Smithson Michael None 100
# The Way You Made Me Daphney Hilton None 100
# Live Again Kelontae Gavin None 100
# Shout Like You Got It Norman Hutchins None 100
# Memory Lane Taking Meds None 100
# Depending On You Clarkwise None 100
# See The Goodness VaShawn Mitchell None 100
# Ju Ju Dolly Christy Costello None 100
# Uranium Baby Christy Costello None 100
# It's Okay Derek Minor None 100
# Major Leagues (freestyle) Connor Flanagan None 100
# Kaleidoscope La Fonda None 100
# Rich Friends J. Monty None 100
# Contentment RUB None 100
# Follow Shama Mrema None 100
# I Just Want You To Be So Happy Liam Finn None 100
# Lie to Me LUVIUM None 100
# Don't Think About the Polar Bear Bridget Kearney None 100
# Play Innocent Craig Wedren None 100
# Retrograde Rematch None 100
# ♡Like Like♡ (Instrumental) Raon None 100
# 雨乙女 Raon None 100
# FILL me in BLACK Raon None 100
# NEON Raon None 100
# ♡Like Like♡ Raon None 100
# FILL me in BLACK - Instrumental Raon None 100
# Saliba Bag Raiders None 100
# Right Here Bag Raiders None 100
# Symptoms Culture Code None 100
# Tonight LUVIUM None 100
# gone, for so long +kets4eki asteria None 100
# Ventilator Blues Deap Vally None 100
# Like A Girl Does Peach PRC None 100
# Bennie & The Jets Enrose None 100
# Dreams Enrose None 100
# Me & You Enrose None 100
# Tattoo Enrose None 100
# Disease Enrose None 100
# Me & You Enrose None 100
# Miscommunikaty L Devine None 100
# Laundry Day L Devine None 100
# Back on The Farm Eyes of Your Eyes None 100
# Magnetron Eyes of Your Eyes None 100
# Need Liz Stuart None 100
# why do I still care? Grim Salvo None 100
# Gravewalker's Anthem MOSSBACK None 100
# Rest of My Life Culture Code None 100
# Gone Too Long Culture Code None 100
# After All Culture Code None 100
# Våran sång Miss Li None 100
# Separate Ways (Worlds Apart) (Stripped Down) [Feat. Lzzy Hale] Daughtry None 100
# You Mean The World To Me Sistah Peaches None 100
# Railin Oligal (From "Blue Star") Govind Vasantha None 100
# Hey Cowboy Devon Cole None 100
# Creeper Thoughts Liz Stuart None 100
# Feel a Way Liz Stuart None 100
# Superhero Audien None 100
# Underneath My Raincoat Studio Killers None 100
# Tazidert Bombino None 100
# Lost Culture Code None 100
# Vatan Mehrdad Asemani None 100
# Sunder scarlet veil None 100
# 빙글빙글 Heize None 100
# Run Jethro Pickett None 100
# INSPEKTOR Tream None 100
# Hibiranran. 泣き虫☔︎ None 100
# Crawl Like a Caterpillar - Sing‐Along Super Simple Songs None 100
# めがもるふぉ～ぜ♡ Smewthie None 100
# Burning Lænz None 100
# Can‐do Dreamer Smewthie None 100
# Time of adult ルンヒャン None 100
# Fottuti per sempre Lo stato sociale None 100
# Just Like Buster Keaton Loudon Wainwright III None 100
# Everybody Needs Someone Noah Cyrus None 100
# Addicted to You Tommy Sparks None 100
# Battle Belongs (Reyer & Retain temix) Reyer None 100
# violent (nightcore version) carolesdaughter None 100
# Sugar Daddy Kylie Morgan None 100
# An Easy Girl ゆいにしお None 100
# Miss Me The Same (with Anson Seabra) Sara Kays None 100
# you & i Malik Harris None 100
# Knees PYTKO None 100
# In Perpetuum Godthrymm None 100
# Keep Your Eyes Open DecemberAir None 100
# Hearts in Pain Angie Rose None 100
# One Percent Better KJ‐52 None 100
# Armor Seth & Nirva None 100
# We Shine at Night 파란노을 None 100
# Glad You Came Licy Be None 100
# Back Again Classmaticc None 100
# Foolish Kurt da Great None 100
# Red Letters Joseph Madigan None 100
# Keep Me Lifted K‐Drama None 100
# We Are (Duet) David Huff None 100
# Amen Right There Emcee N.I.C.E. None 100
# Plague Dogs The Rural Alberta Advantage None 100
# Chirp Connor Price None 100
# Canyonland Sun Tunnels None 100
# Next to Nothing Lorin Klugman None 100
# Slowing Down SAL None 100
# Cowboys Oggy None 100
# Hopeless Romantic Oggy None 100
# This is Going to Be the Year Brett Dennen None 100
# Be Not Afraid Connor Flanagan None 100
# I'm On Fire Nu Tone None 100
# No Longer Bound Forrest Frank None 100
# Cut My Strings STEFANOTTO None 100
# Fruits of My Labor Caleb Gordon None 100
# Another Problem Jake Ziegler None 100
# Ima Hit Yo Block Thee Gift None 100
# Walls Down Talein None 100
# Walk Hulvey None 100
# Madman's Eyes Dave Matthews Band None 100
# Paradise in Hell Arkaden None 100
# Players (DJ Smallz 732 – Jersey club remix) Coi Leray None 100
# Players (DJ Saige remix) Coi Leray None 100
# Players (instrumental) Coi Leray None 100
# Oh, Silly George Skinny Pelembe None 100
# Over It Hoity-Toity None 100
# Aesthetic Girl Oggy None 100
# Feel Alright (Blessed) Erica Campbell None 100
# Understood the Assignment B. Jareal None 100
# On Time Branden Anderson None 100
# Country as Shit Tyler Farr None 100
# LUST FOR LIFE GRIPPA None 100
# SCARY MOVIES GRIPPA None 100
# Mirror M83 None 100
# Another Season Taylor James Donskey None 100
# Help My Unbelief Cindy Randolph None 100
# There's None Like Him FM2 & Intentional None 100
# I Care Fabiana Palladino None 100
# Ephesians 3:20 (My God Is Able) Julian Cross None 100
# What Is This I Got? "Holy Ghost" The New C Lord C'S None 100
# Watchful Eyes Passafire None 100
# You Are My Rock Paul Parker None 100
# Let Him In Maranda Curtis None 100
# Dreamy L D R U None 100
# Can’t Play Myself (A Tribute To Amy) Skepta None 100
# Drums James Hype None 100
# I Don't 2 Lane Summer None 100
# I Will Wait Bri Babineaux None 100
# Celebrate Calvin Bridges None 100
# Sola Carlos Heredia None 100
# Ursula Tomten None 100
# Band and a Drummer Childlike CiCi None 100
# Thirsty Keiana Parks None 100
# I Felt a Funeral, in My Brain Andrew Bird None 100
# Like To Look Sad Lane Lines None 100
# Match Time Sonny Knight None 100
# Field Day Mvkeyyj None 100
# Silver and Gold Will Kellum None 100
# Shark Spray Magdalene Rose None 100
# We Need A Miracle Anthony Evans None 100
# inconsolable AP Macroeconomics None 100
# My Own Dead Black Ends None 100
# Song For A Sickhead Black Ends None 100
# Fears That Keep You Running Samara Lennoxx None 100
# When the Kids Go! Go! Go! Crazy!!! Groovie Ghoulies None 100
# Only God LWO None 100
# Tightrope Hi Crime None 100
# Please Be Nice To Me Forest Ray None 100
# More (Edit) Pale Blue Eyes None 100
# More Pale Blue Eyes None 100
# Disco’s Main Squeeze Cornershop None 100
# Jabse Dekha Hai (Original) Pinky‐Ann‐Rihal None 100
# Disco’s Main Squeeze (Instrumental) Cornershop None 100
# Spacing Out Citrus Clouds None 100
# Crybaby Nanna Bryndís Hilmarsdóttir None 100
# longing for Goldbæk None 100
# Mask Fantom '87 None 100
# Move Upstairs Tim Woodson and The Heirs of Harmony None 100
# Flowers Our Last Night None 100
# Descending to Nowhere Rodrigo y Gabriela None 100
# Everything Else But Rain Until the Ribbon Breaks None 100
# Filosa Margaritas Podridas None 100
# Vómito Margaritas Podridas None 100
# Posters Long Beard None 100
# Dissipate BIAKO None 100
# Drops of Honey Colorjoy None 100
# Blue Eyed Addiction (Renewed Version) Colorjoy None 100
# Vacant Side Colorjoy None 100
# Drops of Honey Colorjoy None 100
# Beautiful People Colorjoy None 100
# Golden Age Colorjoy None 100
# MFSOTSOTR Sidney Gish None 100
# Filming School Sidney Gish None 100
# Tisched Off Bartees Strange None 100
# Keekee'in Bartees Strange None 100
# Arch of Light She is Legend None 100
# Illuminate (dub mix) Avoure None 100
# Illuminate Avoure None 100

# %%
# Get the columns from MusicBrainz API
df.columns
# Out:
# Index(['song_title', 'artist', 'genre', 'popularity'], dtype='object')

# %%
# search the df for a specific song from 2023
df[df["song_title"].str.contains("Illuminate")]
# Out:
#                song_title  artist genre popularity
# 998  Illuminate (dub mix)  Avoure  None        100
# 999            Illuminate  Avoure  None        100

# %%
# output the df to a csv file
df.to_csv("musicbrainz.csv")
